# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Extraction of List of American films of 2018 wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"

df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 264       Columbia Pictures / Gary Sanchez Productions
# 265          Annapurna Pictures / Plan B Entertainment
# 266                                     Focus Features
# 267                                 Annapurna Pictures
# 268                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]
# 2    Simon West (director); Duncan Falconer, Warren...    [4]
# 3    Warwick Thornton (director); David Tranter, St...    [5]
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]
# ..                                                 ...    ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...  [163]
# 265  Adam McKay (director/screenplay); Christian Ba...  [137]
# 266  Mimi Leder (director); Daniel Stiepleman (scre...  [226]
# 267  Karyn Kusama (director); Phil Hay, Matt Manfre...  [258]
# 268  David Slade (director); Charlie Brooker (scree...  [259]
#
# [269 rows x 6 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in d:\anaconda\lib\site-packages (1.7.5)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from tmdbv3api) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->tmdbv3api) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->tmdbv3api) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda\lib\site-packages (from requests->tmdbv3api) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda\lib\site-packages (from requests->tmdbv3api) (2.8)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '9f25db8b9e7a45e7d8066852f43c2613'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get("https://api.themoviedb.org/3/movie/550?api_key=9f25db8b9e7a45e7d8066852f43c2613".format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
            return genre_str.join(genres)
        else:
            np.NaN

# %% [markdown]
# ### Might take some time !!!

# %%
df['Genre'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 264       Columbia Pictures / Gary Sanchez Productions
# 265          Annapurna Pictures / Plan B Entertainment
# 266                                     Focus Features
# 267                                 Annapurna Pictures
# 268                                            Netflix
#
#                                          Cast and crew   Ref.  Genre
# 0    Adam Robitel (director); Leigh Whannell (scree...    [2]  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...    [3]  Drama
# 2    Simon West (director); Duncan Falconer, Warren...    [4]  Drama
# 3    Warwick Thornton (director); David Tranter, St...    [5]  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...    [6]  Drama
# ..                                                 ...    ...    ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...  [163]  Drama
# 265  Adam McKay (director/screenplay); Christian Ba...  [137]  Drama
# 266  Mimi Leder (director); Daniel Stiepleman (scre...  [226]  Drama
# 267  Karyn Kusama (director); Phil Hay, Matt Manfre...  [258]  Drama
# 268  David Slade (director); Charlie Brooker (scree...  [259]  Drama
#
# [269 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','Genre']]

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                          Cast and crew  Genre
# 0    Adam Robitel (director); Leigh Whannell (scree...  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...  Drama
# 2    Simon West (director); Duncan Falconer, Warren...  Drama
# 3    Warwick Thornton (director); David Tranter, St...  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...  Drama
# ..                                                 ...    ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...  Drama
# 265  Adam McKay (director/screenplay); Christian Ba...  Drama
# 266  Mimi Leder (director); Daniel Stiepleman (scre...  Drama
# 267  Karyn Kusama (director); Phil Hay, Matt Manfre...  Drama
# 268  David Slade (director); Charlie Brooker (scree...  Drama
#
# [269 rows x 3 columns]

# %%
def get_director(x):
    if "(director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay);")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay);")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                          Cast and crew  Genre  \
# 0    Adam Robitel (director); Leigh Whannell (scree...  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...  Drama
# 2    Simon West (director); Duncan Falconer, Warren...  Drama
# 3    Warwick Thornton (director); David Tranter, St...  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...  Drama
# ..                                                 ...    ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...  Drama
# 265  Adam McKay (director/screenplay); Christian Ba...  Drama
# 266  Mimi Leder (director); Daniel Stiepleman (scre...  Drama
# 267  Karyn Kusama (director); Phil Hay, Matt Manfre...  Drama
# 268  David Slade (director); Charlie Brooker (scree...  Drama
#
#           director_name     actor_1_name            actor_2_name
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
# [269 rows x 6 columns]

# %%
def get_actor3(x):
    if len((x.split("screenplay);")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 264             Holmes & Watson
# 265                        Vice
# 266         On the Basis of Sex
# 267                   Destroyer
# 268  Black Mirror: Bandersnatch
#
#                                          Cast and crew  Genre  \
# 0    Adam Robitel (director); Leigh Whannell (scree...  Drama
# 1    Lauren Wolkstein (director); Christopher Radcl...  Drama
# 2    Simon West (director); Duncan Falconer, Warren...  Drama
# 3    Warwick Thornton (director); David Tranter, St...  Drama
# 4    Jaume Collet-Serra (director); Byron Willinger...  Drama
# ..                                                 ...    ...
# 264  Etan Cohen (director/screenplay); Will Ferrell...  Drama
# 265  Adam McKay (director/screenplay); Christian Ba...  Drama
# 266  Mimi Leder (director); Daniel Stiepleman (scre...  Drama
# 267  Karyn Kusama (director); Phil Hay, Matt Manfre...  Drama
# 268  David Slade (director); Charlie Brooker (scree...  Drama
#
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name
# 0    Leigh Whannell
# 1     Emily Althaus
# 2        Gemma Chan
# 3               NaN
# 4    Patrick Wilson
# ..              ...
# 264    Rebecca Hall
# 265    Steve Carell
# 266  Justin Theroux
# 267    Toby Kebbell
# 268   Asim Chaudhry
#
# [269 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','Genre','movie_title']]

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name  Genre                 movie_title
# 0    Leigh Whannell  Drama     Insidious: The Last Key
# 1     Emily Althaus  Drama            The Strange Ones
# 2        Gemma Chan  Drama                    Stratton
# 3               NaN  Drama               Sweet Country
# 4    Patrick Wilson  Drama                The Commuter
# ..              ...    ...                         ...
# 264    Rebecca Hall  Drama             Holmes & Watson
# 265    Steve Carell  Drama                        Vice
# 266  Justin Theroux  Drama         On the Basis of Sex
# 267    Toby Kebbell  Drama                   Destroyer
# 268   Asim Chaudhry  Drama  Black Mirror: Bandersnatch
#
# [269 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name']+ ' ' +new_df18['actor_2_name']+ ' ' +new_df18['actor_3_name']+ ' ' +new_df18['director_name']+ ' ' +new_df18['Genre']

# %%
new_df18
# Out:
#           director_name     actor_1_name            actor_2_name  \
# 0          Adam Robitel        Lin Shaye           Angus Sampson
# 1      Lauren Wolkstein    Alex Pettyfer  James Freedson-Jackson
# 2            Simon West   Dominic Cooper          Austin Stowell
# 3      Warwick Thornton      Bryan Brown               Sam Neill
# 4    Jaume Collet-Serra      Liam Neeson            Vera Farmiga
# ..                  ...              ...                     ...
# 264          Etan Cohen     Will Ferrell          John C. Reilly
# 265          Adam McKay   Christian Bale               Amy Adams
# 266          Mimi Leder   Felicity Jones            Armie Hammer
# 267        Karyn Kusama    Nicole Kidman          Sebastian Stan
# 268         David Slade  Fionn Whitehead            Will Poulter
#
#        actor_3_name  Genre                 movie_title  \
# 0    Leigh Whannell  Drama     insidious: the last key
# 1     Emily Althaus  Drama            the strange ones
# 2        Gemma Chan  Drama                    stratton
# 3           unknown  Drama               sweet country
# 4    Patrick Wilson  Drama                the commuter
# ..              ...    ...                         ...
# 264    Rebecca Hall  Drama             holmes & watson
# 265    Steve Carell  Drama                        vice
# 266  Justin Theroux  Drama         on the basis of sex
# 267    Toby Kebbell  Drama                   destroyer
# 268   Asim Chaudhry  Drama  black mirror: bandersnatch
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 264  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 265  Christian Bale Amy Adams Steve Carell Adam McK...
# 266  Felicity Jones Armie Hammer Justin Theroux Mim...
# 267  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 268  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [269 rows x 7 columns]

# %% [markdown]
# ## Extracting features of 2019 movies from wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"

df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
df
# Out:
#                                          Cast and crew   Opening  Opening.1  \
# 0    David F. Sandberg (director); Henry Gayden (sc...     APRIL        5.0
# 1    Kevin Kolsch, Dennis Widmyer (directors); Jeff...     APRIL        5.0
# 2    Robin Bissell (director/screenplay); Taraji P....     APRIL        5.0
# 3    Claire Denis (director/screenplay); Jean-Pol F...     APRIL        5.0
# 4    Brie Larson (director); Samantha McIntyre (scr...     APRIL        5.0
# ..                                                 ...       ...        ...
# 188  Nick Bruno, Troy Quane (directors); Brad Copel...  DECEMBER       25.0
# 189  Greta Gerwig (director/screenplay); Saoirse Ro...  DECEMBER       25.0
# 190  Sam Mendes (director/screenplay); Krysty Wilso...  DECEMBER       25.0
# 191  Destin Daniel Cretton (director/screenplay), A...  DECEMBER       25.0
# 192  Chinonye Chukwu (director/screenplay); Alfre W...  DECEMBER       27.0
#
#                                     Production company   Ref.  \
# 0    Warner Bros. Pictures / New Line Cinema / DC F...   [51]
# 1                                   Paramount Pictures   [52]
# 2                                    STX Entertainment   [53]
# 3                    A24 / Arte / ZDF / Canal+ / Ciné+   [54]
# 4                                              Netflix    NaN
# ..                                                 ...    ...
# 188  20th Century Fox / Blue Sky Studios / Chernin ...  [132]
# 189            Columbia Pictures / Regency Enterprises  [221]
# 190  Universal Pictures / DreamWorks Pictures / Ent...  [222]
# 191          Warner Bros. Pictures / Participant Media  [223]
# 192                                               Neon  [224]
#
#                    Title Unnamed: 0  \
# 0                Shazam!        NaN
# 1           Pet Sematary        NaN
# 2    The Best of Enemies        NaN
# 3              High Life        NaN
# 4          Unicorn Store        NaN
# ..                   ...        ...
# 188    Spies in Disguise        NaN
# 189         Little Women        NaN
# 190                 1917        NaN
# 191           Just Mercy        NaN
# 192             Clemency        NaN
#
#     Wikimedia Commons has media related to Films of the United States, 2019.
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
#
# [193 rows x 8 columns]

# %%
df['Genre'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','Genre']]

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#      Genre
# 0    Drama
# 1    Drama
# 2    Drama
# 3    Drama
# 4    Drama
# ..     ...
# 188  Drama
# 189  Drama
# 190  Drama
# 191  Drama
# 192  Drama
#
# [193 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#      Genre                 director_name
# 0    Drama             David F. Sandberg
# 1    Drama  Kevin Kolsch, Dennis Widmyer
# 2    Drama                 Robin Bissell
# 3    Drama                  Claire Denis
# 4    Drama                   Brie Larson
# ..     ...                           ...
# 188  Drama        Nick Bruno, Troy Quane
# 189  Drama                  Greta Gerwig
# 190  Drama                    Sam Mendes
# 191  Drama         Destin Daniel Cretton
# 192  Drama               Chinonye Chukwu
#
# [193 rows x 4 columns]

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#      Genre                 director_name       actor_1_name
# 0    Drama             David F. Sandberg       Zachary Levi
# 1    Drama  Kevin Kolsch, Dennis Widmyer       Jason Clarke
# 2    Drama                 Robin Bissell   Taraji P. Henson
# 3    Drama                  Claire Denis   Robert Pattinson
# 4    Drama                   Brie Larson        Brie Larson
# ..     ...                           ...                ...
# 188  Drama        Nick Bruno, Troy Quane         Will Smith
# 189  Drama                  Greta Gerwig      Saoirse Ronan
# 190  Drama                    Sam Mendes      George MacKay
# 191  Drama         Destin Daniel Cretton  Michael B. Jordan
# 192  Drama               Chinonye Chukwu      Alfre Woodard
#
# [193 rows x 5 columns]

# %%
def get_actor2(x):
    if len((x.split("screenplay);")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay);")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#      Genre                 director_name       actor_1_name  \
# 0    Drama             David F. Sandberg       Zachary Levi
# 1    Drama  Kevin Kolsch, Dennis Widmyer       Jason Clarke
# 2    Drama                 Robin Bissell   Taraji P. Henson
# 3    Drama                  Claire Denis   Robert Pattinson
# 4    Drama                   Brie Larson        Brie Larson
# ..     ...                           ...                ...
# 188  Drama        Nick Bruno, Troy Quane         Will Smith
# 189  Drama                  Greta Gerwig      Saoirse Ronan
# 190  Drama                    Sam Mendes      George MacKay
# 191  Drama         Destin Daniel Cretton  Michael B. Jordan
# 192  Drama               Chinonye Chukwu      Alfre Woodard
#
#              actor_2_name
# 0             Asher Angel
# 1             Amy Seimetz
# 2            Sam Rockwell
# 3        Juliette Binoche
# 4       Samuel L. Jackson
# ..                    ...
# 188           Tom Holland
# 189           Emma Watson
# 190  Dean-Charles Chapman
# 191            Jamie Foxx
# 192        Wendell Pierce
#
# [193 rows x 6 columns]

# %%
def get_actor3(x):
    if len((x.split("screenplay);")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019
# Out:
#                    Title                                      Cast and crew  \
# 0                Shazam!  David F. Sandberg (director); Henry Gayden (sc...
# 1           Pet Sematary  Kevin Kolsch, Dennis Widmyer (directors); Jeff...
# 2    The Best of Enemies  Robin Bissell (director/screenplay); Taraji P....
# 3              High Life  Claire Denis (director/screenplay); Jean-Pol F...
# 4          Unicorn Store  Brie Larson (director); Samantha McIntyre (scr...
# ..                   ...                                                ...
# 188    Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 189         Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 190                 1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 191           Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 192             Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#      Genre                 director_name       actor_1_name  \
# 0    Drama             David F. Sandberg       Zachary Levi
# 1    Drama  Kevin Kolsch, Dennis Widmyer       Jason Clarke
# 2    Drama                 Robin Bissell   Taraji P. Henson
# 3    Drama                  Claire Denis   Robert Pattinson
# 4    Drama                   Brie Larson        Brie Larson
# ..     ...                           ...                ...
# 188  Drama        Nick Bruno, Troy Quane         Will Smith
# 189  Drama                  Greta Gerwig      Saoirse Ronan
# 190  Drama                    Sam Mendes      George MacKay
# 191  Drama         Destin Daniel Cretton  Michael B. Jordan
# 192  Drama               Chinonye Chukwu      Alfre Woodard
#
#              actor_2_name    actor_3_name
# 0             Asher Angel     Mark Strong
# 1             Amy Seimetz    John Lithgow
# 2            Sam Rockwell             NaN
# 3        Juliette Binoche  André Benjamin
# 4       Samuel L. Jackson     Joan Cusack
# ..                    ...             ...
# 188           Tom Holland   Rashida Jones
# 189           Emma Watson   Florence Pugh
# 190  Dean-Charles Chapman     Mark Strong
# 191            Jamie Foxx     Brie Larson
# 192        Wendell Pierce     Aldis Hodge
#
# [193 rows x 7 columns]

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','Genre','movie_title']]

# %%
new_df19
# Out:
#                     director_name       actor_1_name          actor_2_name  \
# 0               David F. Sandberg       Zachary Levi           Asher Angel
# 1    Kevin Kolsch, Dennis Widmyer       Jason Clarke           Amy Seimetz
# 2                   Robin Bissell   Taraji P. Henson          Sam Rockwell
# 3                    Claire Denis   Robert Pattinson      Juliette Binoche
# 4                     Brie Larson        Brie Larson     Samuel L. Jackson
# ..                            ...                ...                   ...
# 188        Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 189                  Greta Gerwig      Saoirse Ronan           Emma Watson
# 190                    Sam Mendes      George MacKay  Dean-Charles Chapman
# 191         Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 192               Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#        actor_3_name  Genre          movie_title
# 0       Mark Strong  Drama              Shazam!
# 1      John Lithgow  Drama         Pet Sematary
# 2               NaN  Drama  The Best of Enemies
# 3    André Benjamin  Drama            High Life
# 4       Joan Cusack  Drama        Unicorn Store
# ..              ...    ...                  ...
# 188   Rashida Jones  Drama    Spies in Disguise
# 189   Florence Pugh  Drama         Little Women
# 190     Mark Strong  Drama                 1917
# 191     Brie Larson  Drama           Just Mercy
# 192     Aldis Hodge  Drama             Clemency
#
# [193 rows x 6 columns]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name']+ ' ' +new_df19['actor_2_name']+ ' ' +new_df19['actor_3_name']+ ' ' +new_df19['director_name']+ ' ' +new_df19['Genre']

# %%
new_df19
# Out:
#                     director_name       actor_1_name          actor_2_name  \
# 0               David F. Sandberg       Zachary Levi           Asher Angel
# 1    Kevin Kolsch, Dennis Widmyer       Jason Clarke           Amy Seimetz
# 2                   Robin Bissell   Taraji P. Henson          Sam Rockwell
# 3                    Claire Denis   Robert Pattinson      Juliette Binoche
# 4                     Brie Larson        Brie Larson     Samuel L. Jackson
# ..                            ...                ...                   ...
# 188        Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 189                  Greta Gerwig      Saoirse Ronan           Emma Watson
# 190                    Sam Mendes      George MacKay  Dean-Charles Chapman
# 191         Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 192               Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#        actor_3_name  Genre          movie_title  \
# 0       Mark Strong  Drama              shazam!
# 1      John Lithgow  Drama         pet sematary
# 2           unknown  Drama  the best of enemies
# 3    André Benjamin  Drama            high life
# 4       Joan Cusack  Drama        unicorn store
# ..              ...    ...                  ...
# 188   Rashida Jones  Drama    spies in disguise
# 189   Florence Pugh  Drama         little women
# 190     Mark Strong  Drama                 1917
# 191     Brie Larson  Drama           just mercy
# 192     Aldis Hodge  Drama             clemency
#
#                                                   comb
# 0    Zachary Levi Asher Angel Mark Strong David F. ...
# 1    Jason Clarke Amy Seimetz John Lithgow Kevin Ko...
# 2    Taraji P. Henson Sam Rockwell unknown Robin Bi...
# 3    Robert Pattinson Juliette Binoche André Benjam...
# 4    Brie Larson Samuel L. Jackson Joan Cusack Brie...
# ..                                                 ...
# 188  Will Smith Tom Holland Rashida Jones Nick Brun...
# 189  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 190  George MacKay Dean-Charles Chapman Mark Strong...
# 191  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 192  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [193 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)

# %%
my_df
# Out:
#               director_name       actor_1_name            actor_2_name  \
# 0              Adam Robitel          Lin Shaye           Angus Sampson
# 1          Lauren Wolkstein      Alex Pettyfer  James Freedson-Jackson
# 2                Simon West     Dominic Cooper          Austin Stowell
# 3          Warwick Thornton        Bryan Brown               Sam Neill
# 4        Jaume Collet-Serra        Liam Neeson            Vera Farmiga
# ..                      ...                ...                     ...
# 457  Nick Bruno, Troy Quane         Will Smith             Tom Holland
# 458            Greta Gerwig      Saoirse Ronan             Emma Watson
# 459              Sam Mendes      George MacKay    Dean-Charles Chapman
# 460   Destin Daniel Cretton  Michael B. Jordan              Jamie Foxx
# 461         Chinonye Chukwu      Alfre Woodard          Wendell Pierce
#
#        actor_3_name  Genre              movie_title  \
# 0    Leigh Whannell  Drama  insidious: the last key
# 1     Emily Althaus  Drama         the strange ones
# 2        Gemma Chan  Drama                 stratton
# 3           unknown  Drama            sweet country
# 4    Patrick Wilson  Drama             the commuter
# ..              ...    ...                      ...
# 457   Rashida Jones  Drama        spies in disguise
# 458   Florence Pugh  Drama             little women
# 459     Mark Strong  Drama                     1917
# 460     Brie Larson  Drama               just mercy
# 461     Aldis Hodge  Drama                 clemency
#
#                                                   comb
# 0    Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1    Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2    Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3    Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                                                 ...
# 457  Will Smith Tom Holland Rashida Jones Nick Brun...
# 458  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 459  George MacKay Dean-Charles Chapman Mark Strong...
# 460  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 461  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [462 rows x 7 columns]

# %%
old_df = pd.read_csv('D:/Movie-recommendation-system-with-sentimental-analysis/new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action|Adventure|Fantasy|Sci-Fi
# 1           Jack Davenport         Action|Adventure|Fantasy
# 2         Stephanie Sigman        Action|Adventure|Thriller
# 3     Joseph Gordon-Levitt                  Action|Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5359       Keith Stanfield                   Romance Comedy
# 5360     Jean Louisa Kelly                          Romance
# 5361        Tiitus Rantala                   Romance Comedy
# 5362           Gina Holden       Crime Comedy Action Family
# 5363        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5359                       the incredible jessica james
# 5360                                  can't buy my love
# 5361                   thick lashes of lauri mäntyvaara
# 5362                        cop and a half: new recruit
# 5363                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5359  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#       Genre       actor_1_name          actor_2_name          actor_3_name  \
# 0       NaN        CCH Pounder      Joel David Moore             Wes Studi
# 1       NaN        Johnny Depp         Orlando Bloom        Jack Davenport
# 2       NaN    Christoph Waltz          Rory Kinnear      Stephanie Sigman
# 3       NaN          Tom Hardy        Christian Bale  Joseph Gordon-Levitt
# 4       NaN        Doug Walker            Rob Walker               unknown
# ...     ...                ...                   ...                   ...
# 5821  Drama         Will Smith           Tom Holland         Rashida Jones
# 5822  Drama      Saoirse Ronan           Emma Watson         Florence Pugh
# 5823  Drama      George MacKay  Dean-Charles Chapman           Mark Strong
# 5824  Drama  Michael B. Jordan            Jamie Foxx           Brie Larson
# 5825  Drama      Alfre Woodard        Wendell Pierce           Aldis Hodge
#
#                                                    comb  \
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5821  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5822  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5823  George MacKay Dean-Charles Chapman Mark Strong...
# 5824  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5825  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
#                director_name                           genres  \
# 0              James Cameron  Action|Adventure|Fantasy|Sci-Fi
# 1             Gore Verbinski         Action|Adventure|Fantasy
# 2                 Sam Mendes        Action|Adventure|Thriller
# 3          Christopher Nolan                  Action|Thriller
# 4                Doug Walker                      Documentary
# ...                      ...                              ...
# 5821  Nick Bruno, Troy Quane                              NaN
# 5822            Greta Gerwig                              NaN
# 5823              Sam Mendes                              NaN
# 5824   Destin Daniel Cretton                              NaN
# 5825         Chinonye Chukwu                              NaN
#
#                                             movie_title
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5821                                  spies in disguise
# 5822                                       little women
# 5823                                               1917
# 5824                                         just mercy
# 5825                                           clemency
#
# [5826 rows x 8 columns]

# %%
final_df.to_csv('final_data.csv',index = False)
